# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("housing.csv")

# %% [markdown]
# Viewing the data

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %% [markdown]
# Viewing first 5 rows of the data

# %%
data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %% [markdown]
# Checking for same non-null values

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
from sklearn.model_selection import train_test_split

X = data.drop(['median_house_value'], axis=1)
y = data['median_house_value']

# %%
X
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income ocean_proximity
# 0           322.0       126.0         8.3252        NEAR BAY
# 1          2401.0      1138.0         8.3014        NEAR BAY
# 2           496.0       177.0         7.2574        NEAR BAY
# 3           558.0       219.0         5.6431        NEAR BAY
# 4           565.0       259.0         3.8462        NEAR BAY
# ...           ...         ...            ...             ...
# 20635       845.0       330.0         1.5603          INLAND
# 20636       356.0       114.0         2.5568          INLAND
# 20637      1007.0       433.0         1.7000          INLAND
# 20638       741.0       349.0         1.8672          INLAND
# 20639      1387.0       530.0         2.3886          INLAND
#
# [20433 rows x 9 columns]

# %%
y
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: median_house_value, Length: 20433, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
train_data = X_train.join(y_train)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12715    -121.39     38.58                41.0       2577.0           365.0
# 11342    -117.93     33.76                17.0       3341.0           803.0
# 14615    -117.16     32.80                25.0       1399.0           329.0
# 11838    -120.98     39.93                25.0       2220.0           511.0
# 16724    -120.66     35.47                18.0       2474.0           449.0
# ...          ...       ...                 ...          ...             ...
# 10875    -117.89     33.72                23.0       2305.0           538.0
# 9496     -123.70     39.32                18.0       1652.0           352.0
# 18956    -122.04     38.25                38.0       1214.0           244.0
# 20405    -118.88     34.21                26.0       1590.0           196.0
# 17175    -122.47     37.50                18.0       2297.0           416.0
#
#        population  households  median_income ocean_proximity  \
# 12715       913.0       339.0         6.3406          INLAND
# 11342      3381.0       825.0         3.3710       <1H OCEAN
# 14615      1308.0       355.0         2.5682      NEAR OCEAN
# 11838       912.0       449.0         1.8914          INLAND
# 16724      1269.0       431.0         3.9063       <1H OCEAN
# ...           ...         ...            ...             ...
# 10875      2493.0       502.0         3.6618       <1H OCEAN
# 9496        711.0       292.0         3.1071       <1H OCEAN
# 18956       632.0       254.0         2.8438          INLAND
# 20405       654.0       199.0         6.5851       <1H OCEAN
# 17175      1086.0       381.0         4.8750      NEAR OCEAN
#
#        median_house_value
# 12715            448300.0
# 11342            161800.0
# 14615            187500.0
# 11838             87800.0
# 16724            184800.0
# ...                   ...
# 10875            183500.0
# 9496             213200.0
# 18956             94200.0
# 20405            300000.0
# 17175            334600.0
#
# [16346 rows x 10 columns]

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
non_numeric_columns = ['ocean_proximity']
numeric_data = train_data.drop(columns=non_numeric_columns, errors='ignore')
numeric_data.corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924020           -0.108998     0.042721
# latitude            -0.924020  1.000000            0.010997    -0.035536
# housing_median_age  -0.108998  0.010997            1.000000    -0.358770
# total_rooms          0.042721 -0.035536           -0.358770     1.000000
# total_bedrooms       0.068321 -0.067034           -0.319300     0.930603
# population           0.098784 -0.109516           -0.292247     0.856520
# households           0.055172 -0.072002           -0.300425     0.920560
# median_income       -0.018429 -0.077977           -0.111876     0.194673
# median_house_value  -0.049538 -0.141724            0.110017     0.132114
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.068321    0.098784    0.055172      -0.018429
# latitude                 -0.067034   -0.109516   -0.072002      -0.077977
# housing_median_age       -0.319300   -0.292247   -0.300425      -0.111876
# total_rooms               0.930603    0.856520    0.920560       0.194673
# total_bedrooms            1.000000    0.876368    0.980511      -0.012472
# population                0.876368    1.000000    0.905071       0.000675
# households                0.980511    0.905071    1.000000       0.008392
# median_income            -0.012472    0.000675    0.008392       1.000000
# median_house_value        0.045839   -0.028178    0.061356       0.693960
#
#                     median_house_value
# longitude                    -0.049538
# latitude                     -0.141724
# housing_median_age            0.110017
# total_rooms                   0.132114
# total_bedrooms                0.045839
# population                   -0.028178
# households                    0.061356
# median_income                 0.693960
# median_house_value            1.000000

# %%
plt.figure(figsize=(15,8))
sns.heatmap(numeric_data.corr(), annot=True)
# Out:
# <Axes: >

# %%
train_data['total_rooms'] = np.log(train_data['total_rooms'] + 1)
train_data['total_bedrooms'] = np.log(train_data['total_bedrooms'] + 1)
train_data['population'] = np.log(train_data['population'] + 1)
train_data['households'] = np.log(train_data['households'] + 1)

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data.ocean_proximity.value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     7271
# INLAND        5197
# NEAR OCEAN    2068
# NEAR BAY      1808
# ISLAND           2
# Name: count, dtype: int64

# %%
train_data=train_data.join(pd.get_dummies(train_data.ocean_proximity)).drop(['ocean_proximity'], axis=1)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12715    -121.39     38.58                41.0     7.854769        5.902633
# 11342    -117.93     33.76                17.0     8.114325        6.689599
# 14615    -117.16     32.80                25.0     7.244228        5.799093
# 11838    -120.98     39.93                25.0     7.705713        6.238325
# 16724    -120.66     35.47                18.0     7.813996        6.109248
# ...          ...       ...                 ...          ...             ...
# 10875    -117.89     33.72                23.0     7.743270        6.289716
# 9496     -123.70     39.32                18.0     7.410347        5.866468
# 18956    -122.04     38.25                38.0     7.102499        5.501258
# 20405    -118.88     34.21                26.0     7.372118        5.283204
# 17175    -122.47     37.50                18.0     7.739794        6.033086
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 12715    6.817831    5.828946         6.3406            448300.0      False
# 11342    8.126223    6.716595         3.3710            161800.0       True
# 14615    7.177019    5.874931         2.5682            187500.0      False
# 11838    6.816736    6.109248         1.8914             87800.0      False
# 16724    7.146772    6.068426         3.9063            184800.0       True
# ...           ...         ...            ...                 ...        ...
# 10875    7.821643    6.220590         3.6618            183500.0       True
# 9496     6.568078    5.680173         3.1071            213200.0       True
# 18956    6.450470    5.541264         2.8438             94200.0      False
# 20405    6.484635    5.298317         6.5851            300000.0       True
# 17175    6.991177    5.945421         4.8750            334600.0      False
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 12715    True   False     False       False
# 11342   False   False     False       False
# 14615   False   False     False        True
# 11838    True   False     False       False
# 16724   False   False     False       False
# ...       ...     ...       ...         ...
# 10875   False   False     False       False
# 9496    False   False     False       False
# 18956    True   False     False       False
# 20405   False   False     False       False
# 17175   False   False     False        True
#
# [16346 rows x 14 columns]

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(), annot=True, cmap='viridis')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x="latitude", y="longitude", data=train_data, hue="median_house_value", palette="coolwarm")
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %% [markdown]
# Feature Engineering

# %%
train_data['bedroom_ratio'] = train_data['total_bedrooms'] / train_data['total_rooms']
train_data['household_rooms'] = train_data['total_rooms'] / train_data['households']

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Implementing Linear Regression

# %%
from sklearn.linear_model import LinearRegression
X_train, y_train = train_data.drop(['median_house_value'], axis=1), train_data['median_house_value']
reg = LinearRegression()
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
test_data = X_test.join(y_test)

# %%
test_data['total_rooms'] = np.log(test_data['total_rooms'] + 1)
test_data['total_bedrooms'] = np.log(test_data['total_bedrooms'] + 1)
test_data['population'] = np.log(test_data['population'] + 1)
test_data['households'] = np.log(test_data['households'] + 1)

# %%
test_data.ocean_proximity.value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     2959
# INLAND        2193
# NEAR OCEAN     876
# NEAR BAY       712
# ISLAND           3
# Name: count, dtype: int64

# %%
test_data=test_data.join(pd.get_dummies(test_data.ocean_proximity)).drop(['ocean_proximity'], axis=1)

# %%
test_data['bedroom_ratio'] = test_data['total_bedrooms'] / test_data['total_rooms']
test_data['household_rooms'] = test_data['total_rooms'] / test_data['households']

# %%
test_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 14416    -117.24     32.79                20.0     6.869014        5.631212
# 16383    -121.29     38.01                 2.0     8.764678        7.018402
# 7731     -118.14     33.92                31.0     8.224700        6.749931
# 1410     -122.07     37.94                30.0     7.139660        5.624018
# 1335     -121.89     37.99                 4.0     7.683404        6.393591
# ...          ...       ...                 ...          ...             ...
# 17373    -120.43     34.96                24.0     7.915713        6.028279
# 14698    -117.09     32.79                31.0     7.610853        6.035481
# 7826     -118.14     33.90                26.0     7.671361        6.156979
# 2581     -124.08     40.86                18.0     7.160846        6.184149
# 8704     -118.33     33.84                36.0     7.218910        5.529429
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 14416    6.265301    5.541264         3.1838            245800.0      False
# 16383    8.110127    6.864848         4.4871            137900.0      False
# 7731     7.746733    6.687109         3.2237            218200.0       True
# 1410     6.562444    5.402677         2.8920            220800.0      False
# 1335     6.834109    6.135565         4.1016            170500.0      False
# ...           ...         ...            ...                 ...        ...
# 17373    7.066467    6.025866         4.8155            162900.0       True
# 14698    6.771936    5.958425         3.1964            177700.0      False
# 7826     7.048386    6.063785         3.5972            225800.0       True
# 2581     6.692084    6.220590         1.1157            150000.0      False
# 8704     6.505784    5.505332         5.3131            314100.0       True
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN  bedroom_ratio  household_rooms
# 14416   False   False     False        True       0.819799         1.239612
# 16383    True   False     False       False       0.800760         1.276748
# 7731    False   False     False       False       0.820690         1.229934
# 1410    False   False      True       False       0.787715         1.321504
# 1335     True   False     False       False       0.832130         1.252273
# ...       ...     ...       ...         ...            ...              ...
# 17373   False   False     False       False       0.761558         1.313623
# 14698   False   False     False        True       0.793010         1.277326
# 7826    False   False     False       False       0.802593         1.265111
# 2581    False   False     False        True       0.863606         1.151152
# 8704    False   False     False       False       0.765965         1.311258
#
# [6743 rows x 16 columns]

# %%
X_test, y_test = test_data.drop(['median_house_value'], axis=1), test_data['median_house_value']

# %%
X_test
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 14416    -117.24     32.79                20.0     6.869014        5.631212
# 16383    -121.29     38.01                 2.0     8.764678        7.018402
# 7731     -118.14     33.92                31.0     8.224700        6.749931
# 1410     -122.07     37.94                30.0     7.139660        5.624018
# 1335     -121.89     37.99                 4.0     7.683404        6.393591
# ...          ...       ...                 ...          ...             ...
# 17373    -120.43     34.96                24.0     7.915713        6.028279
# 14698    -117.09     32.79                31.0     7.610853        6.035481
# 7826     -118.14     33.90                26.0     7.671361        6.156979
# 2581     -124.08     40.86                18.0     7.160846        6.184149
# 8704     -118.33     33.84                36.0     7.218910        5.529429
#
#        population  households  median_income  <1H OCEAN  INLAND  ISLAND  \
# 14416    6.265301    5.541264         3.1838      False   False   False
# 16383    8.110127    6.864848         4.4871      False    True   False
# 7731     7.746733    6.687109         3.2237       True   False   False
# 1410     6.562444    5.402677         2.8920      False   False   False
# 1335     6.834109    6.135565         4.1016      False    True   False
# ...           ...         ...            ...        ...     ...     ...
# 17373    7.066467    6.025866         4.8155       True   False   False
# 14698    6.771936    5.958425         3.1964      False   False   False
# 7826     7.048386    6.063785         3.5972       True   False   False
# 2581     6.692084    6.220590         1.1157      False   False   False
# 8704     6.505784    5.505332         5.3131       True   False   False
#
#        NEAR BAY  NEAR OCEAN  bedroom_ratio  household_rooms
# 14416     False        True       0.819799         1.239612
# 16383     False       False       0.800760         1.276748
# 7731      False       False       0.820690         1.229934
# 1410       True       False       0.787715         1.321504
# 1335      False       False       0.832130         1.252273
# ...         ...         ...            ...              ...
# 17373     False       False       0.761558         1.313623
# 14698     False        True       0.793010         1.277326
# 7826      False       False       0.802593         1.265111
# 2581      False        True       0.863606         1.151152
# 8704      False       False       0.765965         1.311258
#
# [6743 rows x 15 columns]

# %%
y_test
# Out:
# 14416    245800.0
# 16383    137900.0
# 7731     218200.0
# 1410     220800.0
# 1335     170500.0
#            ...
# 17373    162900.0
# 14698    177700.0
# 7826     225800.0
# 2581     150000.0
# 8704     314100.0
# Name: median_house_value, Length: 6743, dtype: float64

# %%
reg.score(X_test, y_test)
# Out:
# 0.6788374456236956

# %% [markdown]
# Random Forest Model

# %%
from sklearn.ensemble import RandomForestRegressor
forest = RandomForestRegressor()
X_train = train_data.drop(['median_house_value'], axis=1)
y_train = train_data['median_house_value']
forest.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(X_test, y_test)
# Out:
# 0.9437791964638444

# %%
from sklearn.model_selection import GridSearchCV
forest = RandomForestRegressor()
param_grid = {
    "n_estimators": [3, 10, 30],
    "max_features": [2, 4, 6, 8]
}
grid_search = GridSearchCV(forest, param_grid, cv=5, scoring="neg_mean_squared_error", return_train_score=True)
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_features': [2, 4, 6, 8],
#                          'n_estimators': [3, 10, 30]},
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
best_forest = grid_search.best_estimator_

# %%
best_forest.score(X_test, y_test)
# Out:
# 0.939246584015927
